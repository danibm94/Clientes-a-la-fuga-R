# %% [markdown]
# <a href="https://colab.research.google.com/github/danibm94/Clientes-a-la-fuga-R/blob/main/v_0_outlier_Detention_Scenario_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # v.0_outlier_detention_scenario_performance (z-score)

# %% [markdown]
# In statistics, the standard score is the number of standard deviations by which the value of a raw score is above or below the mean value of what is being observed or measured. Raw scores above the mean have positive standard scores, while those below the mean have negative standard scores.
#
# A z-score describes the position of a raw score in terms of its distance from the mean when measured in standard deviation units. It is also known as a standard score, because it allows comparison of scores on different kinds of variables by standardizing the distribution.
#
# What z-score is abnormal?
# As a general rule, z-scores lower than -1.96 or higher than 1.96 are considered unusual and interesting. That is, they are statistically significant outliers.

# %% [markdown]
# # Imports and Functions

# %%
# !pip install caret
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 25.0 MB/s eta 0:00:00
# ...

# %%
# !pip install catboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 MB 13.3 MB/s eta 0:00:00
# ...

# %%
# !pip install lightgbm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install xgboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install category_encoders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 KB 6.1 MB/s eta 0:00:00
# ...

# %%
# !sudo apt-get install unixodbc-dev
# !pip install pyodbc
# !pip install chart_studio
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# unixodbc-dev is already the newest version (2.3.6-0.1build1).
# unixodbc-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.2/333.2 KB 16.4 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 KB 5.0 MB/s eta 0:00:00
# ...

# %%
# !pip install pyodbc
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install --upgrade gspread #IMPORTANT
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 KB 3.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: gspread
#     Found existing installation: gspread 3.4.2
#     Uninstalling gspread-3.4.2:
#       Successfully uninstalled gspread-3.4.2
# ...

# %%
# !pip install "snowflake-connector-python[pandas]" --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 55.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.6/194.6 KB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 KB 11.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 89.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 KB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 83.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.0/36.0 MB 14.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-gbq 0.17.9 requires pyarrow<10.0dev,>=3.0.0, but you have pyarrow 10.0.1 which is incompatible.

# %%
pip install slack_sdk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.9/274.9 KB 12.4 MB/s eta 0:00:00
# ...

# %%
pip install slacker
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for slacker: filename=slacker-0.14.0-py3-none-any.whl size=9396 sha256=3c47eddb2df23fe8b5410ea8a21757c4d5cd237484411cdb4091061b9f99490e
#   Stored in directory: /root/.cache/pip/wheels/55/01/52/9a4c6fa96e0d78aeb76bbea0644dba1749cad7ee1745d869f2
# Successfully built slacker
# ...

# %%
import random
import pandas as pd
pd.set_option('display.max_columns', 100)
import numpy as np

import pyodbc # Connection to DB ==> Snowflake
import snowflake.connector
import sys
import os
import requests
import datetime
import shutil

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import (RandomForestClassifier, BaggingClassifier, VotingClassifier, 
                              GradientBoostingClassifier, RandomForestRegressor, StackingClassifier)
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import (GridSearchCV, cross_val_score, RepeatedStratifiedKFold, 
StratifiedKFold, RandomizedSearchCV)
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import KNNImputer, IterativeImputer

from catboost import CatBoostClassifier

from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

import category_encoders as ce

import warnings
warnings.filterwarnings(action='ignore')
import time

from google.colab import files
from openpyxl.formatting.rule import DataBarRule
#from xlsxwriter.utility import xl_range

# %%
import gspread
print(gspread.__version__) # make sure gspread is of the latest version
from google.colab import auth
from google.auth import default
from google.colab import  drive
# Out:
# 5.7.2

# %%
from slacker import Slacker
from slack_sdk import WebClient
from slack_sdk.errors import SlackApiError

# %%
# Import PyDrive and associated libraries.
# This only needs to be done once in a notebook.
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

""" 
#If authen is needed
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)
"""
# Out:
# ' \n#If authen is needed\nauth.authenticate_user()\ncreds, _ = default()\ngc = gspread.authorize(creds)\n'

# %% [markdown]
# # Functions

# %%
def get_metrics(tags, predictions):
    print('F1 Score:',f1_score(tags, predictions, average='macro'))
    print('Accuracy Score:',accuracy_score(tags, predictions))
    print(confusion_matrix(tags, predictions))

def show_features_importance(model, features, n_best=None):
    if not n_best or n_best > len(features):
        n_best = len(features)
    size = n_best if n_best < len(features) else len(features)
    importance = model.feature_importances_
    importance_dict = {}
    total = 0
    for v,i in sorted(zip(importance, features), reverse=False):
        total += v
        importance_dict[i] = v

    plt.figure(figsize=(10,size/2))
    plt.barh(list(importance_dict.keys())[len(features)-n_best:], 
             list(importance_dict.values())[len(features)-n_best:], color='g')
    plt.show()

def show_missing_unique(df, data=None):
    dfx = pd.DataFrame({'type':df.dtypes,
                  'missing':df.isnull().sum(),
                  '% missing':round(df.isnull().sum()*100/len(df),2),
                  'unique':[len(df[col].unique()) for col in df.columns],
                  '% unique':[round(len(df[col].unique())*100/len(df),2) for col in df.columns]})
    if data:
        dfx['description'] = [x.split(' - ')[1] for x in data.split('\n')]
    return dfx.style.background_gradient(cmap='viridis')

def find_best_cut(y_test, preds_proba, granularity=0.1, low=0, high=1):
    results = [(accuracy_score(y_test, [2 if x[2] >= i else np.argmax(x[:-1]) for x in preds_proba]), i)
               for i in np.arange(low,high,granularity)]
    return sorted(results)[-1]

def plot_corr(df):
    df = df.copy()
    for col in df.select_dtypes(include='O'):
        df[col] = LabelEncoder().fit_transform(df[col])
    plt.figure(figsize=(10,8))
    sns.heatmap(df.corr())
    #display(abs(df.corr()).style.background_gradient(cmap='viridis'))
    
def check_unique_values(df, columns):
    for col in columns:
        print(sorted([x for x in df[col].unique() if x is not np.nan]))
    
def find_features_importance(X_train, y_train):
    xgb = XGBClassifier(random_state=42, n_jobs=-1, verbosity=0).fit(X_train, y_train).feature_importances_
    rf = RandomForestClassifier(random_state=42, n_jobs=-1).fit(X_train, y_train).feature_importances_
    cat = CatBoostClassifier(random_state=42, silent=True).fit(X_train, y_train).feature_importances_
    importances = sorted([(np.mean([x,y,z]),c) for x,y,z,c in zip(xgb, rf, cat, X_train.columns)])
    plt.figure(figsize=(10,len(X_train.columns)/2))
    plt.barh(list(zip(*importances))[1], list(zip(*importances))[0])
    return sorted(importances, reverse=True)

def plot_map(df, color=None):
    plt.figure(figsize=(7,5))
    plt.scatter(df.latitude, df.longitude, s=5, c=color)
    plt.colorbar()

def plot_categoricals(df, tag, col):
    labels = df[col].unique()
    plt.figure(figsize=(10,5))
    qs = [df[tag == i][col].value_counts() for i in np.unique(tag)]
    qs = [[q[l] if l in q else 0 for l in labels] for q in qs]
    acc = np.zeros(len(labels))
    for val, c in zip(qs, ['green','orange','red','blue','yellow','black']):
        plt.bar(labels, val, bottom=acc, color=c)
        acc = acc + val
    plt.xticks(rotation=90)
    plt.title(col)
    plt.show()

# %% [markdown]
# # Connection

# %%
#Connection details
sfusername = "DBARBADILLO"
sfpw = "Barbys_19"
sfaccount = "ii43047.europe-west4.gcp" 
wharehouse = "DORADO_WH"
role = "ANALYST_DORADO"

# %%
# Enter credentials for the Snowflake connector.
ctx = snowflake.connector.connect(
        user=sfusername,
        password=sfpw,
        account=sfaccount,
        wharehouse = wharehouse,
        role = role
    )
cs = ctx.cursor()

# %%
viewquery = """
                   SELECT
    DATE(to_timestamp_ltz(ig.tstamp)) DATE,
	ingamename_default,
    COUNT(DISTINCT(ig.userid)) unique_users,
    round(sum(ig.gross * ig.scalefactor)) spendings
FROM
	stitch.payment.ingametransactions_2000 ig
JOIN 
    (SELECT gameid, modid, scenarioid, betagame, ranked, modversionid, scenarioversionid, nrofplayers, startofgame2, dayofgame,timescale,crdate 
     FROM stitch.global.ultgameproperties WHERE modid = 2001
     
     UNION 
     
     SELECT gameid, modid, scenarioid, betagame, ranked, modversionid, scenarioversionid, nrofplayers, startofgame2, dayofgame,timescale,crdate 
     FROM stitch.global.ultgameproperties_deleted WHERE modid = 2001 ) ug
ON ig.gameid = ug.gameid
JOIN
	(
    SELECT
	l.itemid,
	r.ingamename_default
FROM (
	SELECT
		itemid,
		max(versionid) versionid
	FROM
		stitch.main.scenarios
	WHERE
		ingamename_default != ''
	GROUP BY
		itemid) L
	JOIN (
		SELECT
			itemid,
			versionid,
			ingamename_default
		FROM
			stitch.main.scenarios) R ON l.itemid = r.itemid
		AND l.versionid = r.versionid
    ) s
ON ug.scenarioid = s.itemid
WHERE
	ig.tstamp 
    	BETWEEN DATE_PART(epoch_second, CURRENT_DATE()) - 86400*30 
        AND DATE_PART(epoch_second, CURRENT_DATE())- 1
	AND ig.transactionstate = 'completed'
	AND ig.gross > 0
	AND ig.tutorial = 0
    AND ug.betaGame = 0
    AND ug.ranked = 1
    AND ug.startofgame2 > 0
GROUP BY
    DATE(to_timestamp_ltz(ig.tstamp)),
    s.ingamename_default               
                """ 

cs.execute(viewquery)

dat = cs.fetch_pandas_all()

df = pd.DataFrame(dat)

# %% [markdown]
# # Exploratory Data Analysis (Data Processing if needed)

# %%
df.head()
# Out:
#          DATE                  INGAMENAME_DEFAULT  UNIQUE_USERS   SPENDINGS
# 0  2023-02-07                          FLASHPOINT          4903  24725829.0
# 1  2023-02-06              WORLD WAR 3 (4X SPEED)          6333  87607070.0
# 2  2023-02-05                         WORLD WAR 3          5051  62404271.0
# 3  2023-02-08  WORLD WAR 3  APOCALYPSE (4X SPEED)          1636  29697641.0
# 4  2023-02-09                    BATTLEGROUND USA          4530  59470963.0

# %%
df.describe()
# Out:
#        UNIQUE_USERS     SPENDINGS
# count    620.000000  6.200000e+02
# mean    1324.177419  1.626373e+07
# std     2040.980004  2.583922e+07
# min        1.000000  3.000000e+00
# 25%        4.000000  5.452200e+04
# 50%      157.500000  1.308088e+06
# 75%     1316.000000  2.140507e+07
# max     6704.000000  1.040907e+08

# %%
df.dtypes
#We need to convert DATE, STARTOFGAME, SECONDS_OF_GAME, CRDATE to ---> DATE Format
# Out:
# DATE                   object
# INGAMENAME_DEFAULT     object
# UNIQUE_USERS            int64
# SPENDINGS             float64
# dtype: object

# %%
## Check Unique values per "columnd" = uid, Userid, Total Records
print('Unique Dates: ',len(df['DATE'].unique()))
print('Unique Scenarios: ',len(df['INGAMENAME_DEFAULT'].unique()))
print('Data Set Records: ',df.shape[0])
# Out:
# Unique Dates:  31
# Unique Scenarios:  27
# Data Set Records:  620

# %%
show_missing_unique(df.replace(0, np.nan))
# Out:
# <style type="text/css">
# #T_8c5bb_row0_col1, #T_8c5bb_row0_col2, #T_8c5bb_row1_col1, #T_8c5bb_row1_col2, #T_8c5bb_row1_col3, #T_8c5bb_row1_col4, #T_8c5bb_row2_col1, #T_8c5bb_row2_col2, #T_8c5bb_row3_col1, #T_8c5bb_row3_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_8c5bb_row0_col3, #T_8c5bb_row0_col4 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_8c5bb_row2_col3, #T_8c5bb_row2_col4 {
#   background-color: #1f9f88;
#   color: #f1f1f1;
# }
# #T_8c5bb_row3_col3, #T_8c5bb_row3_col4 {
#   background-color: #fde725;
#   color: #000000;
# }
# </style>
# <table id="T_8c5bb_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >type</th>
#       <th class="col_heading level0 col1" >missing</th>
#       <th class="col_heading level0 col2" >% missing</th>
#       <th class="col_heading level0 col3" >unique</th>
#       <th class="col_heading level0 col4" >% unique</th>
# ...

# %%
#We first need to treat nulls to TMCID, CAMPAIGNID & REFERRERID

# fill NA with = 0 selecting column "COLUMN_NAME"
#df['COLUMN_NAME'].fillna('Unknown', inplace=True)

#COLUMNNAME
# df['COLUMNNAME'].fillna(0, inplace=True)

# %%
#We quickly calculate the nulls again to make sure it worked:
df.isnull().sum()
# Out:
# DATE                  0
# INGAMENAME_DEFAULT    0
# UNIQUE_USERS          0
# SPENDINGS             0
# dtype: int64

# %%
# We separate Categorical and Numerical columns for further use

cat_cols= df.select_dtypes(include=['object','category']).columns
num_cols = df.select_dtypes(exclude=['object','category']).columns

# %%
#We check NUMERICAL columns
df[num_cols].describe()
# Out:
#        UNIQUE_USERS     SPENDINGS
# count    620.000000  6.200000e+02
# mean    1324.177419  1.626373e+07
# std     2040.980004  2.583922e+07
# min        1.000000  3.000000e+00
# 25%        4.000000  5.452200e+04
# 50%      157.500000  1.308088e+06
# 75%     1316.000000  2.140507e+07
# max     6704.000000  1.040907e+08

# %%
#We check CATEGORICAL columns
df[cat_cols].describe()
# Out:
#               DATE INGAMENAME_DEFAULT
# count          620                620
# unique          31                 27
# top     2023-02-05         FLASHPOINT
# freq            24                 31

# %%
#We plot a correlation chart to see high correlation in the columns 
plot_corr(df)

#From this chart we can see
'''
v.0 -->SQL --> we will omit this column in the original query
CORRELATION ON : --> drop all besides EBP
EBP 
EBP REV
NET
NET REV 

CORRELATION ON : --> drop all besides COUNTRY
COUNTRY
Country TIER.... 
grosscurrency (as it is correlated with COUNTRY)

DROP COUNTD INVOICEID as = to purchases

columns to drop:
EBP REV
NET
NET REV 
country_tier_ios
country_tier_android
grosscurrency
COUNT(DISTINCT(INN.INVOICEID))

'''
# Out:
# '\nv.0 -->SQL --> we will omit this column in the original query\nCORRELATION ON : --> drop all besides EBP\nEBP \nEBP REV\nNET\nNET REV \n\nCORRELATION ON : --> drop all besides COUNTRY\nCOUNTRY\nCountry TIER.... \ngrosscurrency (as it is correlated with COUNTRY)\n\nDROP COUNTD INVOICEID as = to purchases\n\ncolumns to drop:\nEBP REV\nNET\nNET REV \ncountry_tier_ios\ncountry_tier_android\ngrosscurrency\nCOUNT(DISTINCT(INN.INVOICEID))\n\n'

# %% [markdown]
# # Grouping for (users & spendings)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DATE                620 non-null    object
#  1   INGAMENAME_DEFAULT  620 non-null    object
#  2   UNIQUE_USERS        620 non-null    int64
#  3   SPENDINGS           620 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 19.5+ KB

# %%
# Extract row and column information the way we want

# UNIQUE_USER DF

#Normal pivot without values from customer
#df_user = df.groupby(['INGAMENAME_DEFAULT', 'DATE']).size().unstack()

# We select COLUMNS needed for each df
df_user = df[['DATE', 'INGAMENAME_DEFAULT','UNIQUE_USERS']]

#We create the PIVOT ACCORDINGLY
df_user = df_user.groupby(['DATE','INGAMENAME_DEFAULT'],as_index = False).sum().pivot('DATE','INGAMENAME_DEFAULT').fillna(0)

#We order Descending to get most relevant values = most recent on top
df_user = df_user.sort_values(by=['DATE'], ascending = False)

df_user.head(10)
# Out:
#                                         UNIQUE_USERS  \
# INGAMENAME_DEFAULT 26P ANTARCTICA ALLIANCE CHALLENGE
# DATE
# 2023-03-07                                       0.0
# 2023-03-06                                       1.0
# 2023-03-05                                       0.0
# 2023-03-04                                       0.0
# 2023-03-03                                       0.0
# 2023-03-02                                       0.0
# 2023-03-01                                       0.0
# 2023-02-28                                       0.0
# 2023-02-27                                       0.0
# 2023-02-26                                       0.0
#
#                                                          \
# INGAMENAME_DEFAULT 26P ANTARCTICA ALLIANCE CHALLENGE 4X
# DATE
# 2023-03-07                                          2.0
# 2023-03-06                                         15.0
# 2023-03-05                                         12.0
# ...

# %%
# SPENDINGS DF

#Normal pivot without values from customer
#df_user = df.groupby(['INGAMENAME_DEFAULT', 'DATE']).size().unstack()

# We select COLUMNS needed for each df
df_spendings = df[['DATE', 'INGAMENAME_DEFAULT','SPENDINGS']]

#We create the PIVOT ACCORDINGLY
df_spendings = df_spendings.groupby(['DATE','INGAMENAME_DEFAULT'],as_index = False).sum().pivot('DATE','INGAMENAME_DEFAULT').fillna(0)

#We order Descending to get most relevant values = most recent on top
df_spendings = df_spendings.sort_values(by=['DATE'], ascending = False)

df_spendings.head(10)
# Out:
#                                            SPENDINGS  \
# INGAMENAME_DEFAULT 26P ANTARCTICA ALLIANCE CHALLENGE
# DATE
# 2023-03-07                                       0.0
# 2023-03-06                                     500.0
# 2023-03-05                                       0.0
# 2023-03-04                                       0.0
# 2023-03-03                                       0.0
# 2023-03-02                                       0.0
# 2023-03-01                                       0.0
# 2023-02-28                                       0.0
# 2023-02-27                                       0.0
# 2023-02-26                                       0.0
#
#                                                          \
# INGAMENAME_DEFAULT 26P ANTARCTICA ALLIANCE CHALLENGE 4X
# DATE
# 2023-03-07                                       3453.0
# 2023-03-06                                     481270.0
# 2023-03-05                                     386496.0
# ...

# %% [markdown]
# # Create Definition for Outlier

# %% [markdown]
# For this 1st approach we are going to use a 2 times Standard Deviation as value
#
#     - Note: we could use z-score values instead of real values (https://datagy.io/python-z-score/)

# %%
df_spendings.head(10)
df_user.head(10)
# Out:
#                                         UNIQUE_USERS  \
# INGAMENAME_DEFAULT 26P ANTARCTICA ALLIANCE CHALLENGE
# DATE
# 2023-03-07                                       0.0
# 2023-03-06                                       1.0
# 2023-03-05                                       0.0
# 2023-03-04                                       0.0
# 2023-03-03                                       0.0
# 2023-03-02                                       0.0
# 2023-03-01                                       0.0
# 2023-02-28                                       0.0
# 2023-02-27                                       0.0
# 2023-02-26                                       0.0
#
#                                                          \
# INGAMENAME_DEFAULT 26P ANTARCTICA ALLIANCE CHALLENGE 4X
# DATE
# 2023-03-07                                          2.0
# 2023-03-06                                         15.0
# 2023-03-05                                         12.0
# ...

# %%
# https://stackoverflow.com/questions/24761998/pandas-compute-z-score-for-all-columns
# We compute zscores for df_users & we create new df

#We first create a copy of the original df
df_user_zscore = df_user.copy()

cols = list(df_user_zscore.columns)
#print(cols)

# now iterate over the remaining columns and create a new zscore column
for col in cols:
    col_zscore = col
    df_user_zscore[col_zscore] = (df_user_zscore[col] - df_user_zscore[col].mean())/df_user_zscore[col].std(ddof=0)
    #df_user_zscore[col_zscore] = (df_user[col] - df_user[col].mean())/df_user[col].std(ddof=0)
    
df_user_zscore

"""
# We could also use this library
from scipy.stats import zscore

df_user.apply(zscore)
"""
# Out:
# '\n# We could also use this library\nfrom scipy.stats import zscore\n\ndf_user.apply(zscore)\n'

# %%
# https://stackoverflow.com/questions/24761998/pandas-compute-z-score-for-all-columns
# We compute zscores for df_spendings & we create new df

#We first create a copy of the original df
df_spendings_zscore = df_spendings.copy()

cols2 = list(df_spendings.columns)

#print(cols)

# now iterate over the remaining columns and create a new zscore column
for col in cols2:
    col_zscore = col
    df_spendings_zscore[col_zscore] = (df_spendings_zscore[col] - df_spendings_zscore[col].mean())/df_spendings_zscore[col].std(ddof=0)
    #df_spendings_zscore[col_zscore] = (df_spendings[col] - df_spendings[col].mean())/df_spendings[col].std(ddof=0)
    
df_spendings_zscore
# Out:
#                                            SPENDINGS  \
# INGAMENAME_DEFAULT 26P ANTARCTICA ALLIANCE CHALLENGE
# DATE
# 2023-03-07                                 -0.311459
# 2023-03-06                                  0.514338
# 2023-03-05                                 -0.311459
# 2023-03-04                                 -0.311459
# 2023-03-03                                 -0.311459
# 2023-03-02                                 -0.311459
# 2023-03-01                                 -0.311459
# 2023-02-28                                 -0.311459
# 2023-02-27                                 -0.311459
# 2023-02-26                                 -0.311459
# 2023-02-25                                 -0.311459
# 2023-02-24                                 -0.311459
# 2023-02-23                                 -0.311459
# 2023-02-22                                 -0.311459
# 2023-02-21                                 -0.311459
# 2023-02-20                                 -0.311459
# ...

# %% [markdown]
# # Apply condition to df (table) & format it

# %% [markdown]
# https://stackoverflow.com/questions/68749539/highlighting-rows-based-on-a-condition

# %%
"""
This works for 1 condition if needed
This works !! do not delete --- 

def highlight_cells(val):
    color = 'green' if val > 1.5 else ''
    color = 'red' if val < -1.5 else ''
    return 'background-color: {}'.format(color)

df_user_zscore.style.applymap(highlight_cells)
"""
# Out:
# "\nThis works for 1 condition if needed\nThis works !! do not delete --- \n\ndef highlight_cells(val):\n    color = 'green' if val > 1.5 else ''\n    color = 'red' if val < -1.5 else ''\n    return 'background-color: {}'.format(color)\n\ndf_user_zscore.style.applymap(highlight_cells)\n"

# %%
#define function for conditional formatting
def highlight_cells2(x):
    if x > 1.5:
        return 'background-color: lightgreen; color: black'
    elif x < -1.5:
        return 'background-color: red; color: black; font-weight: bold' 
    else:
        return None

df_user_export = df_user_zscore.style.applymap(highlight_cells2)

# %%
# we check if logic works for df_users
df_user_zscore.style.format(precision =2).applymap(highlight_cells2)
# Out:
# <style type="text/css">
# #T_c1125_row0_col4, #T_c1125_row0_col5, #T_c1125_row0_col7, #T_c1125_row0_col8, #T_c1125_row0_col11, #T_c1125_row0_col13, #T_c1125_row0_col14, #T_c1125_row0_col15, #T_c1125_row0_col16, #T_c1125_row0_col18, #T_c1125_row0_col19, #T_c1125_row0_col20, #T_c1125_row0_col22, #T_c1125_row0_col23, #T_c1125_row0_col24, #T_c1125_row1_col5, #T_c1125_row12_col7, #T_c1125_row21_col7, #T_c1125_row23_col5, #T_c1125_row26_col15, #T_c1125_row27_col15, #T_c1125_row28_col15, #T_c1125_row29_col15, #T_c1125_row30_col15 {
#   background-color: red;
#   color: black;
#   font-weight: bold;
# }
# ...

# %%
# we check if logic works for df_users
df_spendings_zscore.style.format(precision =2).applymap(highlight_cells2)
# Out:
# <style type="text/css">
# #T_c84b6_row0_col4, #T_c84b6_row0_col5, #T_c84b6_row0_col8, #T_c84b6_row0_col11, #T_c84b6_row0_col13, #T_c84b6_row0_col14, #T_c84b6_row0_col18, #T_c84b6_row0_col20, #T_c84b6_row0_col22, #T_c84b6_row0_col23, #T_c84b6_row0_col24, #T_c84b6_row1_col5, #T_c84b6_row23_col5, #T_c84b6_row30_col14 {
#   background-color: red;
#   color: black;
#   font-weight: bold;
# }
# ...

# %%
# We visualize real values as 2nd sheet (business purpose)

df_spendings.style.format(precision =0).bar()
# Out:
# <style type="text/css">
# ...

# %%
# We visualize real values as 2nd sheet (business purpose)

df_user.style.format(precision =0).bar()
# Out:
# <style type="text/css">
# ...

# %%
# This would our completed dfs (ALL ROWS) 

df_spendings_zscore_export = df_spendings_zscore.style.format(precision =2).applymap(highlight_cells2)
df_user_zscore_export = df_user_zscore.style.format(precision =2).applymap(highlight_cells2)
df_spendings_export = df_spendings.style.format(precision =0).bar()
df_user_export = df_user.style.format(precision =0).bar()

# %%
# drop first row

df_spendings_zscore_export = df_spendings_zscore.apply(lambda x : x.drop(x.index[:1])).style.format(precision =2).applymap(highlight_cells2)
df_user_zscore_export = df_user_zscore.apply(lambda x : x.drop(x.index[:1])).style.format(precision =2).applymap(highlight_cells2)
df_spendings_export = df_spendings.apply(lambda x : x.drop(x.index[:1])).style.format(precision =0).bar()
df_user_export = df_user.apply(lambda x : x.drop(x.index[:1])).style.format(precision =0).bar()

# %%
df_user_export
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# # Export df Table

# %%
import datetime

# %%
#We create the logic for TODAY to add to files name
Current_Date = datetime.datetime.today().strftime ('%d_%b_%Y')


# Guardar un csv file with TODAYS within the name (reporting purposes)
#Exportar prevision en la carpeta conteniendo "exporting date" for tracking purposes

# %%
str(Current_Date)
# Out:
# '07_Mar_2023'

# %%
"""
# If we need to save it locally use this:

File path is determined here
# WE SELECT a  path as directory

os.getcwd()

os.chdir('c:\\Users\\daniel.barbadillo\\Downloads')

#files.download('df_spendings_zscore_export.xlsx') # this is to save locally = Download

"""
#Name of the file can be modified in here
"""
df_export.to_csv( str(Current_Date) +'_DanielBarbadillo_' +'extract.csv')
"""
# Out:
# "\ndf_export.to_csv( str(Current_Date) +'_DanielBarbadillo_' +'extract.csv')\n"

# %% [markdown]
# ## Export ZScore tables

# %%
#If authen is needed
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# %%
#Drive folder id = 14E-Y-aqTqBixv1dIlPT6jz2R6WYae0QA
#files.download('df_spendings_zscore_export.xlsx') # this is to save locally = Download

#Name of the file can be modified in here

# we first connect to Drive
from google.colab import drive
drive.mount('/content/drive')

# we set up  the path
os.getcwd()
os.chdir('/content/drive/My Drive/Reports/Python/') # we set up location first


#Exports for zscore dfs with name format

df_spendings_zscore_export.to_excel( str(Current_Date) + '_df_spendings_zscore_export.xlsx',sheet_name='df_spendings_zscore_export', engine='openpyxl') 
df_user_zscore_export.to_excel(str(Current_Date) + '_df_user_zscore_export.xlsx',sheet_name='df_user_zscore_export', engine='openpyxl')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Export Bar tables

# %%
"""
df_spendings_export.to_excel('df_spendings_export.xlsx',sheet_name='df_spendings_export', engine='openpyxl') 
files.download('df_spendings_export.xlsx')
"""
"""
#Export for bar formatting doesnt work... So we will need to:
1- Save excel file
2-Open & write
3-Apply Barchart function/viz
4-Save with PROPER NAME

https://stackoverflow.com/questions/61031550/write-excel-file-from-pandas-with-bar-chart-formatting-within-column-created-usi


"""
# Out:
# '\n#Export for bar formatting doesnt work... So we will need to:\n1- Save excel file\n2-Open & write\n3-Apply Barchart function/viz\n4-Save with PROPER NAME\n\nhttps://stackoverflow.com/questions/61031550/write-excel-file-from-pandas-with-bar-chart-formatting-within-column-created-usi\n\n\n'

# %% [markdown]
# #FINAL VISUALIZATION

# %%
df_spendings_zscore_export
# Out:
# <style type="text/css">
# #T_0b871_row0_col1, #T_0b871_row0_col7, #T_0b871_row1_col1, #T_0b871_row1_col15, #T_0b871_row1_col19, #T_0b871_row1_col26, #T_0b871_row2_col1, #T_0b871_row2_col4, #T_0b871_row2_col7, #T_0b871_row2_col14, #T_0b871_row2_col26, #T_0b871_row3_col11, #T_0b871_row3_col15, #T_0b871_row4_col15, #T_0b871_row6_col3, #T_0b871_row9_col22, #T_0b871_row10_col3, #T_0b871_row10_col5, #T_0b871_row10_col20, #T_0b871_row15_col25, #T_0b871_row16_col21, #T_0b871_row16_col25, #T_0b871_row17_col5, #T_0b871_row17_col21, #T_0b871_row18_col5, #T_0b871_row19_col25, #T_0b871_row20_col1, #T_0b871_row21_col10, #T_0b871_row21_col12, #T_0b871_row22_col18, #T_0b871_row23_col0, #T_0b871_row24_col19, #T_0b871_row24_col25, #T_0b871_row25_col25, #T_0b871_row26_col0, #T_0b871_row26_col11, #T_0b871_row28_col6, #T_0b871_row28_col9, #T_0b871_row28_col16, #T_0b871_row29_col2, #T_0b871_row29_col9, #T_0b871_row29_col16, #T_0b871_row29_col17 {
#   background-color: lightgreen;
#   color: black;
# }
# ...

# %%
df_user_zscore_export
# Out:
# <style type="text/css">
# #T_98894_row0_col0, #T_98894_row0_col1, #T_98894_row1_col3, #T_98894_row1_col7, #T_98894_row1_col26, #T_98894_row2_col26, #T_98894_row3_col3, #T_98894_row3_col11, #T_98894_row16_col21, #T_98894_row17_col21, #T_98894_row18_col10, #T_98894_row19_col12, #T_98894_row19_col25, #T_98894_row20_col1, #T_98894_row21_col10, #T_98894_row21_col12, #T_98894_row22_col0, #T_98894_row22_col8, #T_98894_row22_col12, #T_98894_row23_col0, #T_98894_row23_col5, #T_98894_row23_col6, #T_98894_row23_col8, #T_98894_row24_col0, #T_98894_row24_col19, #T_98894_row24_col25, #T_98894_row25_col0, #T_98894_row26_col0, #T_98894_row26_col16, #T_98894_row27_col6, #T_98894_row27_col9, #T_98894_row27_col16, #T_98894_row27_col19, #T_98894_row28_col6, #T_98894_row28_col9, #T_98894_row28_col11, #T_98894_row28_col12, #T_98894_row28_col16, #T_98894_row28_col19, #T_98894_row29_col2, #T_98894_row29_col9, #T_98894_row29_col17, #T_98894_row29_col19 {
#   background-color: lightgreen;
#   color: black;
# ...

# %%
df_spendings_export
# Out:
# <style type="text/css">
# #T_56e7d_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 15.8%, transparent 15.8%);
# }
# #T_56e7d_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 79.1%, transparent 79.1%);
# }
# ...

# %%
df_user_export
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# # SLACK MESSAGES

# %%
token = "xoxb-200362093586-4847426811331-51EUOx62M7Hurc4msIW05ydi"
# token2 = cp8wNK68o5hVrMNDCu82qju2

# %%
slack_token = token
client = WebClient(token=slack_token)
"""
#Send TEXT

try:
    response = client.chat_postMessage(
        channel="C04QGKHNTT9",
        text= "TEST! 2 Dani" 
    )
except SlackApiError as e:
    assert e.response["error"]
"""
# Out:
# '\n#Send TEXT\n\ntry:\n    response = client.chat_postMessage(\n        channel="C04QGKHNTT9",\n        text= "TEST! 2 Dani" \n    )\nexcept SlackApiError as e:\n    assert e.response["error"]\n'

# %%
# SEND FILE via Slack --> Scenario zscore 
#### USER FILE

# we set up  the path
os.getcwd()
os.chdir('/content/drive/My Drive/Reports/Python/') # we set up location first


try:
    response = client.files_upload_v2(
        channel="C04QGKHNTT9",
        title= str(Current_Date)+"_Users_zscore_export.xlsx",
        file="./"+str(Current_Date)+"_df_user_zscore_export.xlsx",
        initial_comment= str(Current_Date)+" Users Z-Score view:"
    )
except SlackApiError as e:
    assert e.response["error"]

# %%
# SEND FILE via Slack --> SPENDINGS zscore 
#### SPENDINGS FILE

# we set up  the path
os.getcwd()
os.chdir('/content/drive/My Drive/Reports/Python/') # we set up location first


try:
    response = client.files_upload_v2(
        channel="C04QGKHNTT9",
        title= str(Current_Date)+"_Spendings_zscore_export.xlsx",
        file="./"+str(Current_Date)+"_df_spendings_zscore_export.xlsx",
        initial_comment= str(Current_Date)+" Spendings Z-Score view:"
    )
except SlackApiError as e:
    assert e.response["error"]

# %%
"""
# SEND FILE via Slack --> KPIs zscore 
#### KPIs FILE

# we set up  the path
os.getcwd()
os.chdir('/content/drive/My Drive/Reports/Python/') # we set up location first

try:
    response = client.files_upload_v2(
        channel="C04QGKHNTT9",
        title= str(Current_Date)+"_KPIs_zscore_export.xlsx",
        file= "./"+str(Current_Date)+"_kpi_zscore.xlsx",
        initial_comment= str(Current_Date)+" KPIs Z-Score view:"
    )
except SlackApiError as e:
    assert e.response["error"]

"""
# Out:
# '\n# SEND FILE via Slack --> KPIs zscore \n#### KPIs FILE\n\n# we set up  the path\nos.getcwd()\nos.chdir(\'/content/drive/My Drive/Reports/Python/\') # we set up location first\n\ntry:\n    response = client.files_upload_v2(\n        channel="C04QGKHNTT9",\n        title= str(Current_Date)+"_KPIs_zscore_export.xlsx",\n        file= "./"+str(Current_Date)+"_kpi_zscore.xlsx",\n        initial_comment= str(Current_Date)+" KPIs Z-Score view:"\n    )\nexcept SlackApiError as e:\n    assert e.response["error"]\n\n'

# %% [markdown]
# # END

# %%
print("Code has run succesfully")
# Out:
# Code has run succesfully
